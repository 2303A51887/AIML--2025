# %% [markdown]
# <a href="https://colab.research.google.com/github/2303A51887/AIML--2025/blob/main/Lab_06.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Upload the file using Google Colab uploader

# %%
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python

import numpy as np
import pandas as pd

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

import plotly.express as px

# %%
df = pd.read_csv('/content/Anime_rank.csv')
df.head()
# Out:
#    UID                               Title  Rank Stream type  Episodes  \
# 0    1                   Sousou no Frieren     1         TV       28.0
# 1    2    Fullmetal Alchemist: Brotherhood     2         TV       64.0
# 2    3                         Steins;Gate     3         TV       24.0
# 3    4                            Gintama°     4         TV       51.0
# 4    5  Shingeki no Kyojin Season 3 Part 2     5         TV       10.0
#
#   Start date   End date     Members  Score
# 0  Sep 2023    Mar 2024    800,615    9.35
# 1  Apr 2009    Jul 2010  3,373,923    9.09
# 2  Apr 2011    Sep 2011  2,584,616    9.07
# 3  Apr 2015    Mar 2016    636,631    9.06
# 4  Apr 2019    Jul 2019  2,305,044    9.05

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Menampilkan informasi umum tentang dataset
print("\nInformasi dataset:")
print(df.info())
# Out:
# Informasi dataset:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8650 entries, 0 to 8649
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   UID          8650 non-null   int64
#  1   Title        8650 non-null   object
#  2   Rank         8650 non-null   int64
#  3   Stream type  8650 non-null   object
#  4   Episodes     8608 non-null   float64
#  5   Start date   8648 non-null   object
#  6   End date     8551 non-null   object
#  7   Members      8650 non-null   object
#  8   Score        8650 non-null   float64
# dtypes: float64(2), int64(2), object(5)
# memory usage: 608.3+ KB
# None

# %%
# Menampilkan ringkasan statistik
print("\nRingkasan statistik dari dataset:")
print(df.describe())
# Out:
# Ringkasan statistik dari dataset:
#                UID         Rank     Episodes        Score
# count  8650.000000  8650.000000  8608.000000  8650.000000
# mean   4325.500000  4325.500000    15.245818     7.039057
# std    2497.184248  2497.184248    34.188955     0.593492
# min       1.000000     1.000000     1.000000     6.150000
# 25%    2163.250000  2163.250000     1.000000     6.550000
# 50%    4325.500000  4325.500000    11.000000     6.970000
# 75%    6487.750000  6487.750000    13.000000     7.420000
# max    8650.000000  8650.000000  1787.000000     9.350000

# %%
# Menampilkan jumlah nilai yang hilang untuk setiap kolom
print("\nJumlah nilai yang hilang untuk setiap kolom:")
print(df.isnull().sum())
# Out:
# Jumlah nilai yang hilang untuk setiap kolom:
# UID             0
# Title           0
# Rank            0
# Stream type     0
# Episodes       42
# Start date      2
# End date       99
# Members         0
# Score           0
# dtype: int64

# %%
# Menghapus baris duplikat
df.drop_duplicates(inplace=True)

# %%
# Menangani nilai yang hilang
# Mengisi nilai yang hilang dengan rata-rata untuk kolom Episodes
df['Episodes'].fillna(df['Episodes'].mean(), inplace=True)

# %%
# Menghapus baris dengan nilai yang hilang pada kolom Start date dan End date
df_cleaned = df.dropna(subset=['Start date', 'End date'])

# Memeriksa kembali apakah ada nilai yang hilang
print("\nJumlah nilai yang hilang setelah pembersihan data:")
print(df_cleaned.isnull().sum())

# Menampilkan informasi umum tentang dataset setelah pembersihan
print("\nInformasi dataset setelah pembersihan:")
print(df_cleaned.info())
# Out:
# Jumlah nilai yang hilang setelah pembersihan data:
# UID            0
# Title          0
# Rank           0
# Stream type    0
# Episodes       0
# Start date     0
# End date       0
# Members        0
# Score          0
# dtype: int64
#
# Informasi dataset setelah pembersihan:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8551 entries, 0 to 8649
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   UID          8551 non-null   int64
#  1   Title        8551 non-null   object
#  2   Rank         8551 non-null   int64
#  3   Stream type  8551 non-null   object
#  4   Episodes     8551 non-null   float64
#  5   Start date   8551 non-null   object
#  6   End date     8551 non-null   object
#  7   Members      8551 non-null   object
#  8   Score        8551 non-null   float64
# dtypes: float64(2), int64(2), object(5)
# memory usage: 668.0+ KB
# None

# %%
# Memeriksa kembali apakah ada nilai yang hilang
print("\nJumlah nilai yang hilang setelah pembersihan data:")
print(df_cleaned.isnull().sum())
# Out:
# Jumlah nilai yang hilang setelah pembersihan data:
# UID            0
# Title          0
# Rank           0
# Stream type    0
# Episodes       0
# Start date     0
# End date       0
# Members        0
# Score          0
# dtype: int64

# %%
# Menampilkan informasi umum tentang dataset setelah pembersihan
print("\nInformasi dataset setelah pembersihan:")
print(df_cleaned.info())
# Out:
# Informasi dataset setelah pembersihan:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8551 entries, 0 to 8649
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   UID          8551 non-null   int64
#  1   Title        8551 non-null   object
#  2   Rank         8551 non-null   int64
#  3   Stream type  8551 non-null   object
#  4   Episodes     8551 non-null   float64
#  5   Start date   8551 non-null   object
#  6   End date     8551 non-null   object
#  7   Members      8551 non-null   object
#  8   Score        8551 non-null   float64
# dtypes: float64(2), int64(2), object(5)
# memory usage: 668.0+ KB
# None

# %%
# Menghapus karakter yang tidak sesuai (misalnya tanda koma)
df_cleaned['Members'] = df_cleaned['Members'].str.replace(',', '')

# Mengubah tipe data menjadi integer
df_cleaned['Members'] = df_cleaned['Members'].astype(int)

# Memeriksa kembali tipe data setelah konversi
print(df_cleaned.info())

# Menampilkan 5 baris pertama untuk memeriksa hasil konversi
print(df_cleaned.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8551 entries, 0 to 8649
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   UID          8551 non-null   int64
#  1   Title        8551 non-null   object
#  2   Rank         8551 non-null   int64
#  3   Stream type  8551 non-null   object
#  4   Episodes     8551 non-null   float64
#  5   Start date   8551 non-null   object
#  6   End date     8551 non-null   object
#  7   Members      8551 non-null   int64
#  8   Score        8551 non-null   float64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 668.0+ KB
# None
#    UID                               Title  Rank Stream type  Episodes  \
# 0    1                   Sousou no Frieren     1         TV       28.0
# 1    2    Fullmetal Alchemist: Brotherhood     2         TV       64.0
# 2    3                         Steins;Gate     3         TV       24.0
# ...

# %%
# Mengubah tipe data kolom Start date dan End date menjadi datetime
df_cleaned['Start date'] = pd.to_datetime(df_cleaned['Start date'], errors='coerce')
df_cleaned['End date'] = pd.to_datetime(df_cleaned['End date'], errors='coerce')

# Memeriksa kembali tipe data setelah konversi
print(df_cleaned.info())

# Menampilkan 5 baris pertama untuk memeriksa hasil konversi
print(df_cleaned.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8551 entries, 0 to 8649
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   UID          8551 non-null   int64
#  1   Title        8551 non-null   object
#  2   Rank         8551 non-null   int64
#  3   Stream type  8551 non-null   object
#  4   Episodes     8551 non-null   float64
#  5   Start date   8551 non-null   datetime64[ns]
#  6   End date     8551 non-null   datetime64[ns]
#  7   Members      8551 non-null   int64
#  8   Score        8551 non-null   float64
# dtypes: datetime64[ns](2), float64(2), int64(3), object(2)
# memory usage: 668.0+ KB
# None
#    UID                               Title  Rank Stream type  Episodes  \
# 0    1                   Sousou no Frieren     1         TV       28.0
# 1    2    Fullmetal Alchemist: Brotherhood     2         TV       64.0
# 2    3                         Steins;Gate     3         TV       24.0
# ...

# %%
# Plot distribusi rating anime
fig = px.histogram(df_cleaned, x='Score', nbins=20, title='Distribusi Rating Anime',
                   labels={'Score': 'Rating'}, marginal='box', hover_data=df_cleaned.columns)
fig.update_layout(bargap=0.2)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.scatter(df_cleaned, x='Episodes', y='Score', title='Korelasi antara Jumlah Episode dan Rating',
                 labels={'Episodes':'Jumlah Episode', 'Score':'Rating'}, color_discrete_sequence=['#00CC96'])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.scatter(df_cleaned, x='Members', y='Episodes', title='Korelasi antara Jumlah Member dan Episode',
                 labels={'Members':'Jumlah Member', 'Episodes':'Jumlah Episode'}, color_discrete_sequence=['#00CC96'])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Ekstraksi tahun dari Start date
df_cleaned['Start Year'] = df_cleaned['Start date'].dt.year

# Distribusi anime berdasarkan tahun rilis
fig = px.histogram(df_cleaned, x='Start Year', title='Distribusi Anime Berdasarkan Tahun Rilis',
                   labels={'Start Year': 'Tahun Rilis'}, nbins=len(df_cleaned['Start Year'].unique()))
fig.update_layout(bargap=0.2)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.histogram(df_cleaned, x='Members', nbins=20, title='Distribusi Jumlah Anggota (Members) yang Menonton Anime', labels={'Members': 'Jumlah Anggota'})
fig.update_layout(bargap=0.2)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Menghitung durasi produksi dalam hari
df_cleaned['Production Duration'] = (df_cleaned['End date'] - df_cleaned['Start date']).dt.days

fig = px.histogram(df_cleaned, x='Production Duration', nbins=20, title='Distribusi Durasi Produksi Anime (dalam hari)', labels={'Production Duration': 'Durasi Produksi (hari)'})
fig.update_layout(bargap=0.2)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Ekstraksi tahun dari Start date
df_cleaned['Start Year'] = df_cleaned['Start date'].dt.year

# Menghitung jumlah anime yang dirilis per tahun
anime_per_year = df_cleaned['Start Year'].value_counts().reset_index()
anime_per_year.columns = ['Year', 'Count']
anime_per_year = anime_per_year.sort_values('Year')

# Visualisasi tren jumlah anime yang dirilis per tahun
fig = px.line(anime_per_year, x='Year', y='Count', title='Tren Jumlah Anime yang Dirilis per Tahun', labels={'Year': 'Tahun', 'Count': 'Jumlah Anime'})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Menghitung rata-rata rating per tahun
rating_per_year = df_cleaned.groupby('Start Year')['Score'].mean().reset_index()
rating_per_year = rating_per_year.sort_values('Start Year')

# Visualisasi tren rating anime per tahun
fig = px.line(rating_per_year, x='Start Year', y='Score', title='Tren Rating Anime per Tahun', labels={'Start Year': 'Tahun', 'Score': 'Rata-rata Rating'})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Menghitung rata-rata jumlah anggota per tahun
members_per_year = df_cleaned.groupby('Start Year')['Members'].mean().reset_index()
members_per_year = members_per_year.sort_values('Start Year')

# Visualisasi tren jumlah anggota per tahun
fig = px.line(members_per_year, x='Start Year', y='Members', title='Tren Jumlah Anggota per Tahun', labels={'Start Year': 'Tahun', 'Members': 'Rata-rata Jumlah Anggota'})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Menghitung durasi produksi dalam hari
df_cleaned['Production Duration'] = (df_cleaned['End date'] - df_cleaned['Start date']).dt.days

# Menghitung rata-rata durasi produksi per tahun
duration_per_year = df_cleaned.groupby('Start Year')['Production Duration'].mean().reset_index()
duration_per_year = duration_per_year.sort_values('Start Year')

# Visualisasi tren durasi produksi per tahun
fig = px.line(duration_per_year, x='Start Year', y='Production Duration', title='Tren Durasi Produksi per Tahun', labels={'Start Year': 'Tahun', 'Production Duration': 'Rata-rata Durasi Produksi (hari)'})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Ekstraksi musim dari Start date
df_cleaned['Season'] = df_cleaned['Start date'].dt.month % 12 // 3 + 1
season_mapping = {1: 'Winter', 2: 'Spring', 3: 'Summer', 4: 'Fall'}
df_cleaned['Season'] = df_cleaned['Season'].map(season_mapping)

# Menghitung jumlah anime yang dirilis per musim
anime_per_season = df_cleaned['Season'].value_counts().reset_index()
anime_per_season.columns = ['Season', 'Count']
anime_per_season = anime_per_season.sort_values('Season')

# Visualisasi tren jumlah anime yang dirilis per musim
fig = px.bar(anime_per_season, x='Season', y='Count', title='Tren Jumlah Anime yang Dirilis per Musim', labels={'Season': 'Musim', 'Count': 'Jumlah Anime'})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Mengurutkan data berdasarkan jumlah anggota dan memilih top 10 anime
top_anime_popular = df_cleaned.sort_values(by='Members', ascending=False).head(10)

# Visualisasi top 10 anime terpopuler
fig = px.bar(top_anime_popular, x='Title', y='Members', title='Top 10 Anime Terpopuler', labels={'Title': 'Judul Anime', 'Members': 'Jumlah Anggota'})
fig.update_layout(xaxis_tickangle=-45)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Top 10 Anime dengan Jumlah Anggota Terendah
least_popular_anime = df_cleaned.sort_values(by='Members', ascending=True).head(10)

fig_least_popular = px.bar(least_popular_anime, x='Title', y='Members',
                           title='Top 10 Anime dengan Jumlah Anggota Terendah',
                           labels={'Title': 'Judul Anime', 'Members': 'Jumlah Anggota'})
fig_least_popular.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Mengurutkan data berdasarkan rating dan memilih top 10 anime
top_anime_rated = df_cleaned.sort_values(by='Score', ascending=False).head(10)

# Visualisasi top 10 anime dengan rating tertinggi
fig = px.bar(top_anime_rated, x='Title', y='Score', title='Top 10 Anime dengan Rating Tertinggi', labels={'Title': 'Judul Anime', 'Score': 'Rating'})
fig.update_layout(xaxis_tickangle=-45)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Top 10 Anime dengan Rating Terendah
lowest_rated_anime = df_cleaned.sort_values(by='Score', ascending=True).head(10)

fig_lowest_ratings = px.bar(lowest_rated_anime, x='Title', y='Score',
                            title='Top 10 Anime dengan Rating Terendah',
                            labels={'title': 'Judul Anime', 'rating': 'Rating'})
fig_lowest_ratings.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# Memilih fitur dan target
features = df_cleaned[['Episodes', 'Members', 'Production Duration']]
target = df_cleaned['Score']

# Memisahkan data menjadi set pelatihan dan pengujian
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)

# Melakukan normalisasi fitur
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Membuat model regresi linear
model = LinearRegression()

# Melatih model
model.fit(X_train_scaled, y_train)

# Memprediksi pada set pengujian
y_pred = model.predict(X_test_scaled)

# Evaluasi model
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("Mean Absolute Error (MAE):", mae)
print("Mean Squared Error (MSE):", mse)
print("R-squared (R²):", r2)
# Out:
# Mean Absolute Error (MAE): 0.4500568988192131
# Mean Squared Error (MSE): 0.2984603186475442
# R-squared (R²): 0.19717890452628595

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV

# Definisikan parameter grid untuk tuning
param_grid = {
    'n_estimators': [100, 200, 300],
    'max_depth': [10, 20, 30],
    'min_samples_split': [2, 5, 10]
}

# Inisiasi model
rf_model = RandomForestRegressor(random_state=42)

# GridSearchCV untuk hyperparameter tuning
grid_search = GridSearchCV(estimator=rf_model, param_grid=param_grid, cv=3, n_jobs=-1, verbose=2)
grid_search.fit(X_train_scaled, y_train)

# Model terbaik
best_rf_model = grid_search.best_estimator_

# Prediksi
y_pred = best_rf_model.predict(X_test_scaled)

# Evaluasi model
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("Random Forest Regressor - Rating Anime")
print("Mean Absolute Error (MAE):", mae)
print("Mean Squared Error (MSE):", mse)
print("R-squared (R²):", r2)
# Out:
# Fitting 3 folds for each of 27 candidates, totalling 81 fits
# Random Forest Regressor - Rating Anime
# Mean Absolute Error (MAE): 0.3617937778313971
# Mean Squared Error (MSE): 0.20947052635715244
# R-squared (R²): 0.43655036555095383

# %%
# Memilih fitur dan target untuk prediksi popularitas
features = df_cleaned[['Episodes', 'Score', 'Production Duration']]
target = df_cleaned['Members']

# Memisahkan data menjadi set pelatihan dan pengujian
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)

# Melakukan normalisasi fitur
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Membuat model regresi linear
model = LinearRegression()

# Melatih model
model.fit(X_train_scaled, y_train)

# Memprediksi pada set pengujian
y_pred = model.predict(X_test_scaled)

# Evaluasi model
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("Mean Absolute Error (MAE):", mae)
print("Mean Squared Error (MSE):", mse)
print("R-squared (R²):", r2)
# Out:
# Mean Absolute Error (MAE): 125289.19774201029
# Mean Squared Error (MSE): 58254263087.135414
# R-squared (R²): 0.20185962493543264

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report

# Memilih fitur dan target untuk prediksi tipe tayangan
features = df_cleaned[['Episodes', 'Score', 'Members']]
target = df_cleaned['Stream type']

# Memisahkan data menjadi set pelatihan dan pengujian
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)

# Melakukan normalisasi fitur
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Membuat model klasifikasi Random Forest
model = RandomForestClassifier(random_state=42)

# Melatih model
model.fit(X_train_scaled, y_train)

# Memprediksi pada set pengujian
y_pred = model.predict(X_test_scaled)

# Evaluasi model
accuracy = accuracy_score(y_test, y_pred)
report = classification_report(y_test, y_pred)

print("Accuracy:", accuracy)
print("Classification Report:\n", report)
# Out:
# Accuracy: 0.6499123319696084
# Classification Report:
#                precision    recall  f1-score   support
#
#       Movie        0.54      0.66      0.60       293
#         ONA        0.50      0.34      0.40       185
#         OVA        0.35      0.40      0.38       197
#     Special        0.31      0.24      0.27       183
#          TV        0.90      0.96      0.93       761
#  TV Special        0.10      0.07      0.08        92
#
#     accuracy                           0.65      1711
#    macro avg       0.45      0.44      0.44      1711
# weighted avg       0.63      0.65      0.64      1711

# %%
from sklearn.ensemble import RandomForestClassifier

# Definisikan parameter grid untuk tuning
param_grid = {
    'n_estimators': [100, 200, 300],
    'max_depth': [10, 20, 30],
    'min_samples_split': [2, 5, 10]
}

# Inisiasi model
rf_classifier = RandomForestClassifier(random_state=42)

# GridSearchCV untuk hyperparameter tuning
grid_search = GridSearchCV(estimator=rf_classifier, param_grid=param_grid, cv=3, n_jobs=-1, verbose=2)
grid_search.fit(X_train_scaled, y_train)

# Model terbaik
best_rf_classifier = grid_search.best_estimator_

# Prediksi
y_pred = best_rf_classifier.predict(X_test_scaled)

# Evaluasi model
accuracy = accuracy_score(y_test, y_pred)
report = classification_report(y_test, y_pred)

print("Random Forest Classifier - Tipe Tayangan")
print("Accuracy:", accuracy)
print("Classification Report:\n", report)
# Out:
# Fitting 3 folds for each of 27 candidates, totalling 81 fits
# Random Forest Classifier - Tipe Tayangan
# Accuracy: 0.6826417299824664
# Classification Report:
#                precision    recall  f1-score   support
#
#       Movie        0.50      0.91      0.65       293
#         ONA        0.72      0.32      0.44       185
#         OVA        0.41      0.41      0.41       197
#     Special        0.29      0.11      0.16       183
#          TV        0.90      0.97      0.94       761
#  TV Special        0.00      0.00      0.00        92
#
#     accuracy                           0.68      1711
#    macro avg       0.47      0.46      0.43      1711
# weighted avg       0.64      0.68      0.64      1711
